# %% [markdown]
# <a href="https://colab.research.google.com/github/jcebermudo/experiments/blob/main/token_counter/sp_counter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("google/gemma-3-27b-it")

def count_tokens(text: str) -> int:
    return len(tokenizer.encode(text))

print("Type a prompt to count tokens. Type 'quit' to exit.\n")

while True:
    try:
        prompt = input("Prompt> ")
    except (EOFError, KeyboardInterrupt):
        print("\nBye!")
        break

    if prompt.strip().lower() in {"quit", "exit", "q"}:
        print("Bye!")
        break

    tokens = count_tokens(prompt)
    print(f"  Prompt tokens: {tokens}")
    print(f"  Budget remaining for answer: {1000 - 20 - tokens}\n")
# Out:
# config.json:   0%|          | 0.00/972 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.16M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/33.4M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/35.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/662 [00:00<?, ?B/s]
# Type a prompt to count tokens. Type 'quit' to exit.
#
# Prompt> hello world
#   Prompt tokens: 3
#   Budget remaining for answer: 977
#
# Prompt> tiktokenizer
#   Prompt tokens: 3
#   Budget remaining for answer: 977
#
#
# Bye!
